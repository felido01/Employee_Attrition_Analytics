# %% [markdown]
# # EMPLOYER ATTRITION ANALYSIS BY FELIX IDOWU

# %% [markdown]
# ## Project Goal: Analyze employee attrition data to identify key factors influencing employee turnover and provide actionable recommendations

# %% [markdown]
# ## Key Questions:
# ### What factors contribute most to attrition?
# ### Which employee groups are at higher risk of leaving?
# ### What insights can HR teams act on to reduce attrition?

# %% [markdown]
# ## Importing Libraries needed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#loading Dataset
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset?resource=download&select=WA_Fn-UseC_-HR-Employee-Attrition.csv
df=pd.read_csv('Employee Attrition Analysis - HR Employee Attrition (1).csv')

# %% [markdown]
# ## Data Exploration

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below college  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below college        Medical              1
#
#    EmployeeNumber  ... PerformanceRating StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobSatisfaction', 'RelationshipSatisfaction',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   object
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
df.describe() # statisical understanding
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000         1470.0
# mean     36.923810   802.485714          9.192517            1.0
# std       9.135373   403.509100          8.106864            0.0
# min      18.000000   102.000000          1.000000            1.0
# 25%      30.000000   465.000000          2.000000            1.0
# 50%      36.000000   802.000000          7.000000            1.0
# 75%      43.000000  1157.000000         14.000000            1.0
# max      60.000000  1499.000000         29.000000            1.0
#
#        EmployeeNumber   HourlyRate  NumCompaniesWorked  PercentSalaryHike  \
# count     1470.000000  1470.000000         1470.000000        1470.000000
# mean      1024.865306    65.891156            2.693197          15.209524
# std        602.024335    20.329428            2.498009           3.659938
# min          1.000000    30.000000            0.000000          11.000000
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome      Education EducationField  EmployeeCount  \
# ...

# %%
# Attrition Distribution
sns.countplot(x='Attrition', data=df)
plt.title('Attrition Distribution')
plt.show()

# %% [markdown]
# ## Cleaning Dataset

# %%
#Checking for null cell
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobSatisfaction             0
# RelationshipSatisfaction    0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# corr = df.corr()
# sns.heatmap(corr, annot=True, cmap="coolwarm")
# plt.title("Correlation Heatmap")
# plt.show()

# %%
#Getting the Attrition Data
#A_Data is Attrition Data
A_Data= df[df.Attrition== 'Yes']
A_Data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome      Education    EducationField  EmployeeCount  \
# ...

# %%
A_Data.shape
# Out:
# (237, 35)

# %% [markdown]
# ## We are going to be dealing Mostly with the Attrition Data For our Exploratory Data Analysis.
# ## From the Shape of the Attrition Data, We can see that the rows in total is 237, which means number of Attrition is 237

# %%
A_Data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobSatisfaction', 'RelationshipSatisfaction',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
jbr=jbr.reset_index()
jbr
# Out:
#                      JobRole              Department  Attrition
# 0  Healthcare Representative  Research & Development          9
# 1            Human Resources         Human Resources         12
# 2      Laboratory Technician  Research & Development         62
# 3                    Manager  Research & Development          3
# 4                    Manager                   Sales          2
# 5     Manufacturing Director  Research & Development         10
# 6          Research Director  Research & Development          2
# 7         Research Scientist  Research & Development         47
# 8            Sales Executive                   Sales         57
# 9       Sales Representative                   Sales         33

# %% [markdown]
# ## From here we can Conclude that the Department and Job roles with the highest attrition is  	Research & Development,	Laboratory Technician respectively with 62 Total Attrition

# %% [markdown]
# ## Other Key Metrics to Attrition will be done on the Dashboard. Further Analysis of Key Metrics will end here to avoid tautology of Analysis

# %%
#Using Aggregation Function groupby
jbr=A_Data.groupby(['JobRole','Department'])['Attrition'].count()
jbr
# Out:
# JobRole                    Department
# Healthcare Representative  Research & Development     9
# Human Resources            Human Resources           12
# Laboratory Technician      Research & Development    62
# Manager                    Research & Development     3
#                            Sales                      2
# Manufacturing Director     Research & Development    10
# Research Director          Research & Development     2
# Research Scientist         Research & Development    47
# Sales Executive            Sales                     57
# Sales Representative       Sales                     33
# Name: Attrition, dtype: int64

# %% [markdown]
# # The Analysis Was done on Power Bi to Improve Understanding

# %%
from IPython.display import IFrame

# Use your Power BI embed link here
embed_url = "https://app.powerbi.com/reportEmbed?reportId=53cda70a-db29-43c3-80cd-440f9cdc4121&autoAuth=true&ctid=a36e1a13-c829-4154-8635-f2516711db50"
IFrame(embed_url, width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://app.powerbi.com/reportEmbed?reportId=53cda70a-db29-43c3-80cd-440f9cdc4121&autoAuth=true&ctid=a36e1a13-c829-4154-8635-f2516711db50"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#Copy the link and paste to browser to view dashboard
# https://app.powerbi.com/links/xA_4TyAVMm?ctid=a36e1a13-c829-4154-8635-f2516711db50&pbi_source=linkShare
